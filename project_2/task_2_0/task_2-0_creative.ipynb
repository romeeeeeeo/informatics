# %%
print("========================\nДобро пожаловать, Роман", sep=",", end="!")
print("\nСтудент 1 курса")
print("Удачи в обучении", end="!")
print("\n========================")
# Out:
# ...
# Добро пожаловать, Роман!
# Студент 1 курса
# Удачи в обучении!
# ...
